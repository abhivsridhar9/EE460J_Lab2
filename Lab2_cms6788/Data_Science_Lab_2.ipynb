# %%
#Question 1import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot
import glob
#p1
df1 = pd.read_csv("Lab2_Data/DF1", index_col=0)


#sns.pairplot(df1)
#pd.plotting.scatter_matrix(df1)

#p2
cov_matrix = df1.cov()
#print(cov_matrix)

#p3
mean = [0,0,0]
covariance = [[10, 0, 0],
              [0, 20, .8],
              [0, .8, 30]]
sample_cov_list = []
sample_num_list = []
x = 5
while x < 5000:
    gaus = np.random.multivariate_normal(mean, covariance, x)
    sample_cov = np.cov(gaus, rowvar=False)
    sample_cov_list.append(sample_cov[1][2]-.8)
    sample_num_list.append(x)
    #print("sample cov\n", sample_cov)
    x = x + 100
#print(sample_cov_list)
plot.scatter(sample_num_list,sample_cov_list)
plot.show()

# %%
#Problem 2
df2 = pd.read_csv("Lab2_Data/DF2", index_col=0)
sns.scatterplot(data=df2, x='0', y='1')

cov_matrix = np.cov(df2, rowvar=False)
print("cov matrix:", cov_matrix)
df_feature1 = df2.iloc[:, 1].tolist()
df_feature2 = df2.iloc[:, 0].tolist()
y = cov_matrix


#print("Mean Feature 1:", np.mean(df2[['0']].to_numpy()))
#print("Variance Feature 1:", np.var(df2[['0']].to_numpy()))
#print("Mean Feature 2:", np.mean(df2[['1']].to_numpy()))
#print("Variance Feature 2:", np.var(df2[['1']].to_numpy()))
#q = np.array([[np.mean(df_feature1), np.var(df_feature1)],[np.mean(df_feature2), np.var(df_feature2)]])
#q_inv = np.linalg.inv(q)
#print(q_inv)
#z = df2[['0','1']].to_numpy()
#print(z)
# Out:
# cov matrix: [[1.00464777 0.9942424 ]
#  [0.9942424  1.00415964]]

# %%
#Problem 3

#P1
num_people = input("Input Number of Names to be returned")
year = input("Year to query:")
name = "yob"+ year+".txt"
print(name)
df = pd.read_csv("Names/"+name)
print(df)
freq_list = df.iloc[:int(num_people),0].tolist()
print(freq_list)
# Out:
# yob.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\CONNOR~1\AppData\Local\Temp/ipykernel_22200/3720852238.py in <module>
#       6 name = "yob"+ year+".txt"
#       7 print(name)
# ----> 8 df = pd.read_csv("Names/"+name)
#       9 print(df)
#      10 freq_list = df.iloc[:int(num_people),0].tolist()
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# c:\users\connor smith\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Names/yob.txt'

# %%
#P2
import glob
import os
#name = input("Choose a name to be returned")
path = "Names"
joined_files = os.path.join("/Names", "*")
filenames = glob.glob(path+"/*")
print(filenames)
for filename in filenames:
    df = pd.read_csv(filename)
    print(df)
concatenated_df   = pd.concat(map(pd.read_csv,["Names/yob1880.txt"], ["Names/yob1881.txt"]), ignore_index=True)
#df = pd.read_csv("Names/yob1880.txt")
print(df)
print(concatenated_df)
